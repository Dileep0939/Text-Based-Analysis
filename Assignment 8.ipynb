# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Named Entity Recognition</p>

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Importing Libraries</p>

# %%
# Importing necessary libraries
import spacy
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
import en_core_web_sm
from collections import Counter
from spacy import displacy

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Loading SpaCy Language Model</p>

# %%
# Loading SpaCy Language Model
nlp = en_core_web_sm.load()

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">NER on Sample Text</p>

# %%
# NER on Sample Text
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)
# Printing tokens in the sample text
for token in doc:
    print(token, end=" | ")
print()
# Out:
# My | best | friend | Ryan | Peters | likes | fancy | adventure | games | . |

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Displaying NLP Tokens in DataFrame</p>

# %%
# Function to display NLP tokens in DataFrame
def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i, 'text': t.text, 'lemma_': t.lemma_, 'is_stop': t.is_stop, 'is_alpha': t.is_alpha, 'pos_': t.pos_, 'dep_': t.dep_, 'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
# Displaying tokens in DataFrame
print(display_nlp(doc))
# Out:
#         text     lemma_  is_stop  is_alpha   pos_      dep_ ent_type_ ent_iob_
# 0         My         my     True      True   PRON      poss                  O
# 1       best       good    False      True    ADJ      amod                  O
# 2     friend     friend    False      True   NOUN     nsubj                  O
# 3       Ryan       Ryan    False      True  PROPN  compound    PERSON        B
# 4     Peters     Peters    False      True  PROPN     appos    PERSON        I
# 5      likes       like    False      True   VERB      ROOT                  O
# 6      fancy      fancy    False      True    ADJ      amod                  O
# 7  adventure  adventure    False      True   NOUN  compound                  O
# 8      games       game    False      True   NOUN      dobj                  O

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Filtering Non-Stop and Non-Punctuation Tokens</p>

# %%
# Filtering non-stop and non-punctuation tokens from a text
text = "Dear Ryan, we need to sit down and talk. Regards, Pete"
doc = nlp(text)
non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Dear, Ryan, need, sit, talk, Regards, Pete]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Extracting Nouns and Proper Nouns</p>

# %%
# Extracting nouns and proper nouns from a text
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)
nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [friend, Ryan, Peters, adventure, games]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Extracting Named Entities</p>

# %%
# Extracting named entities from a text
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Ryan Peters, PERSON)

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Named Entities in a Complex Sentence</p>

# %%
# Named entities in a complex sentence
text = "James O'Neill, chairman of World Cargo Inc, lives in San Francisco."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (James O'Neill, PERSON) (World Cargo Inc, ORG) (San Francisco, GPE)

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Visualizing Named Entities</p>

# %%
# Visualizing named entities
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James O'Neill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Cargo Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , lives in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Extracting Named Entities from Web Page</p>

# %%
# Extracting named entities from a web page
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.google.com/search?q=artificial+intelligence&oq=artificial&gs_lcrp=EgZjaHJvbWUqDQgAEAAYgwEYsQMYgAQyDQgAEAAYgwEYsQMYgAQyDAgBEEUYORixAxiABDINCAIQABiDARixAxiABDIKCAMQABixAxiABDINCAQQABiDARixAxiABDIKCAUQABixAxiABDINCAYQABiDARixAxiABDINCAcQLhiDARixAxiABDINCAgQABiDARixAxiABDIHCAkQABiABNIBCDQ2MzhqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8')
article = nlp(ny_bb)

print(len(article.ents))
displacy.render(article, style='ent', jupyter=True)
# Out:
# 48
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">artificial intelligence - Google SearchGoogle×Please click here if you are not redirected within
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a few seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# .    AllNewsImagesVideos
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maps  Shopping  Books  Search
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tools    Any timeAny timePast hourPast
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  hoursPast weekPast monthPast yearAll resultsAll resultsVerbatimArtificial intelligence (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) makes it possible for machines to learn from experience, adjust to new inputs and perform human-like tasks. Most
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  examples that you hear about
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  – from chess-playing computers to self-driving cars – rely heavily on deep learning and natural language processing.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (AI): What it is and why it matters -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Institutewww.sas.com ›
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Insights
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     › Analytics InsightsAbout Featured SnippetsPeople
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  also askHow is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  used today?What are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  types of AI?Is there a free AI I can use?Who invented AI?Artificial intelligence - Wikipediaen.wikipedia.org
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ›
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  wiki
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ›
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  Artificial_intelligenceArtificial intelligence (AI), in its broadest sense, is intelligence exhibited by machines, particularly computer systems, as opposed to the natural ...What is Artificial Intelligence (AI)? - IBMwww.ibm.com › topics
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ›
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  artificial-intelligenceArtificial intelligence, or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , is technology that enables computers and machines to simulate human intelligence and problem-solving capabilities.Artificial intelligenceField of studyView allArtificial intelligence, in its broadest sense, is intelligence exhibited by machines, particularly computer systems, as opposed to the natural intelligence of living beings. WikipediaProgramming language: PythonWhat Is Artificial Intelligence (AI)? |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Cloudcloud.google.com
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ›
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  learn
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ›
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  what-is-artificial-intelligenceWhat is artificial intelligence? What are artificial neural networks?
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  benefits, uses cases, and examples.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radiu

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Counting and Displaying Label Counts</p>

# %%
# Counting and displaying label counts
labels = [x.label_ for x in article.ents]
label_counts = Counter(labels)
print(label_counts)

items = [ent.text for ent in article.ents]
print(Counter(items).most_common(5))
# Out:
# Counter({'ORG': 29, 'CARDINAL': 5, 'PERSON': 4, 'PRODUCT': 3, 'GPE': 3, 'DATE': 2, 'TIME': 1, 'NORP': 1})
# [('AI', 10), ('›', 9), ('Artificial Intelligence', 2), ('SAS', 2), ('a few seconds', 1)]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Splitting Text into Sentences</p>

# %%
# Splitting text into sentences
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# artificial intelligence - Google SearchGoogle×Please click here if you are not redirected within a few seconds.

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Visualizing Named Entities in a Sentence</p>

# %%
# Visualizing named entities in a sentence
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">artificial intelligence - Google SearchGoogle×Please click here if you are not redirected within
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a few seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# .    </div></span>

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Token Analysis in a Sentence</p>

# %%
# Token analysis in a sentence
print([(x.orth_,x.pos_, x.lemma_) for x in
  [y for y in nlp(str(sentences[0])) if not y.is_stop and y.pos_ != 'PUNCT']])
# Out:
# [('artificial', 'ADJ', 'artificial'), ('intelligence', 'NOUN', 'intelligence'), ('Google', 'PROPN', 'Google'), ('SearchGoogle×Please', 'PROPN', 'SearchGoogle×Please'), ('click', 'VERB', 'click'), ('redirected', 'VERB', 'redirect'), ('seconds', 'NOUN', 'second'), ('   ', 'SPACE', '   ')]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Visualizing Dependency Parsing in a Sentence</p>

# %%
# Visualizing dependency parsing in a sentence
displacy.render(nlp(str(sentences[0])), style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="75d395939d144affa91378a1ba9e6bc0-0" class="displacy" width="1970" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">intelligence -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">SearchGoogle×Please</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">click</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">here</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">redirected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">within</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">few</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">seconds.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75d395939d144affa91378a1ba9e6bc0-0-0" stroke-width="2px" d="M70,362.0 C70,182.0 395.0,182.0 395.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75d395939d144affa91378a1ba9e6bc0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,364.0 L62,352.0 78,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75d395939d144affa91378a1ba9e6bc0-0-1" stroke-width="2px" d="M190,362.0 C190,242.0 390.0,242.0 390.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75d395939d144affa91378a1ba9e6bc0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,364.0 L182,352.0 198,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75d395939d144affa91378a1ba9e6bc0-0-2" stroke-width="2px" d="M310,362.0 C310,302.0 385.0,302.0 385.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75d395939d144affa91378a1ba9e6bc0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,364.0 L302,352.0 318,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75d395939d144affa91378a1ba9e6bc0-0-3" stroke-width="2px" d="M430,362.0 C430,302.0 505.0,302.0 505.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75d395939d144affa91378a1ba9e6bc0-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,364.0 L422,352.0 438,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75d395939d144affa91378a1ba9e6bc0-0-4" stroke-width="2px" d="M550,362.0 C550,302.0 625.0,302.0 625.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75d395939d144affa91378a1ba9e6bc0-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M625.0,364.0 L633.0,352.0 617.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75d395939d144affa91378a1ba9e6bc0-0-5" stroke-width="2px" d="M790,362.0 C790,122.0 1240.0,122.0 1240.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75d395939d144affa91378a1ba9e6bc0-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,364.0 L782,352.0 798,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75d395939d144affa91378a1ba9e6bc0-0-6" stroke-width="2px" d="M910,362.0 C910,182.0 1235.0,182.0 1235.0,362.0" fill="none" st

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Article 2</p>

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Extracting Named Entities from Web Page</p>

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
# Extracting named entities from another web page
ny_bb = url_to_string('https://www.cnn.com/middleeast/live-news/israel-hamas-war-gaza-news-03-26-24/index.html')
article = nlp(ny_bb)

print(len(article.ents))
displacy.render(article, style='ent', jupyter=True)
# Out:
# 1208
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 26, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Hamas war |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  values your feedback                                                                                                                                                                                                                             1. How relevant is this ad to you?
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Did you encounter any technical issues?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Video player was slow to load content                                                                                                                                                                                                                                                                                                                                                             Video content never loaded                                                                                                                                                                                                                                                                                                                                                             Ad froze or did not finish loading                                                                                                                                                                                                                                                                                                                                                             Video content did not start after ad
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Audio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  on ad was too loud                                                                                                                                                                                                                                                                                                                                                             Other issues                                                                                                                                                                                                                                                                                                                                                                                                                                                               Ad never loaded                                                                                                                                                                                                                                                                                                                                                             Ad prevented/slowed the page from loading

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Counting and Displaying Label Counts</p>

# %%
# Counting and displaying label counts for the second article
labels = [x.label_ for x in article.ents]
label_counts = Counter(labels)
print(label_counts)

items = [ent.text for ent in article.ents]
print(Counter(items).most_common(5))
# Out:
# Counter({'GPE': 348, 'ORG': 312, 'PERSON': 180, 'NORP': 130, 'DATE': 129, 'CARDINAL': 80, 'TIME': 7, 'FAC': 6, 'LOC': 5, 'ORDINAL': 5, 'QUANTITY': 5, 'PRODUCT': 1})
# [('CNN', 92), ('Gaza', 87), ('Israeli', 80), ('Israel', 77), ('US', 59)]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Splitting Text into Sentences</p>

# %%
# Splitting text into sentences for the second article
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
#                               March 26, 2024 Israel-Hamas war | CNN                                                                                                                                                                                                                                                                                                                                                                                                      CNN values your feedback                                                                                                                                                                                                                             1.

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Visualizing Named Entities in a Sentence</p>

# %%
# Visualizing named entities in a sentence for the second article
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 26, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -Hamas war |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  values your feedback
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</div></span>

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Token Analysis in a Sentence</p>

# %%
# Token analysis in a sentence for the second article
print([(x.orth_,x.pos_, x.lemma_) for x in
  [y for y in nlp(str(sentences[0])) if not y.is_stop and y.pos_ != 'PUNCT']])
# Out:
# [('                              ', 'SPACE', '                              '), ('March', 'PROPN', 'March'), ('26', 'NUM', '26'), ('2024', 'NUM', '2024'), ('Israel', 'PROPN', 'Israel'), ('Hamas', 'PROPN', 'Hamas'), ('war', 'NOUN', 'war'), ('|', 'NOUN', '|'), ('CNN', 'PROPN', 'CNN'), ('                                                                                                                                                                                                                                                                                                                                                                                                     ', 'SPACE', '                                                                                                                                                                                                                                                                                                                                                                                                     '), ('CNN', 'PROPN', 'CNN'), ('values', 'VERB', 'value'), ('feedback', 'NOUN', 'feedback'), ('                                                                                                                                                                                                                            ', 'SPACE', '                                                                                                                                                                                                                            '), ('1', 'NUM', '1')]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Visualizing Dependency Parsing in a Sentence</p>

# %%
# Visualizing dependency parsing in a sentence for the second article
displacy.render(nlp(str(sentences[0])), style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3c8b1bc3b8a143d3b93d1f5d1a154cb9-0" class="displacy" width="1970" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">                              </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">March</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">26,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">2024</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Israel-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Hamas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">war</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">|</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">CNN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">                                                                                                                                                                                                                                                                                                                                                                                                     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">CNN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">values</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">feedback</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">                                                                                                                                                                                                                            </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">1.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-0" stroke-width="2px" d="M70,242.0 C70,182.0 155.0,182.0 155.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-1" stroke-width="2px" d="M190,242.0 C190,2.0 1370.0,2.0 1370.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-2" stroke-width="2px" d="M190,242.0 C190,182.0 275.0,182.0 275.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M275.0,244.0 L283.0,232.0 267.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-3" stroke-width="2px" d="M430,242.0 C430,122.0 760.0,122.0 760.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-4" stroke-width="2px" d="M550,242.0 C550,182.0 635.0,182.0 635.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,244.0 L542,232.0 558,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8b1bc3b8a143d3b93d1f5d1a154cb9-0-5" stroke-width="2px" d="M670,242.0 C670,182.0 755.0,182.0 755.0,242.0"

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Spanish Article</p>

# %%
import spacy
# Load the Spanish language model
nlp = spacy.load("es_core_news_sm")

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Extracting Named Entities from Web Page</p>

# %%
# Extracting named entities from a Spanish web page
ny_bb = url_to_string('https://english.elpais.com/')
article = nlp(ny_bb)

print(len(article.ents))
displacy.render(article, style='ent', jupyter=True)
# Out:
# 234
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">EL
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PAÍS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  English____Mar 27, 2024|Updated 01:59 CET|Select:- - -EspañaAméricaMéxicoColombiaChileArgentinaUSAsubscribeHHOLALOG INInternationalU.S.Economy &amp; BusinessScienceHealthTechnologyClimatePeopleLifestyleOpinionSportsMar 27, 2024|Updated 01:59
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CET|subscribe_Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  seems inclined not to restrict access to abortion pill
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Seisdedos|WashingtonAt
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the oral arguments in the mifepristone case
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     majority of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  justices
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     appeared skeptical about the legal standing of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  a Christian doctors’ association to sue the Food and Drug AdministrationNew
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  judge imposes gag order on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump in hush money caseJudge Juan M. Merchan on Tuesday cited Trump’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  previous comments about him and others involved in the case,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     as well
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  as a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     looming April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  15 trial date,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in granting the prosecution’s request for a gag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     orderBaltimore’s largest bridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  collapses after
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     being struck by shipMiguel Jiménez|BaltimoreEmergency crews
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  have rescued two
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people from the water and are searching for six others
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The collision took place as the vessel was leaving the bay towards the Atlantic OceanGallery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The collapse of the Baltimore bridgeUS Defense Secretary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  emphasizes
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the urgency of alleviating the crisis in Gaza to Israeli counterpartMaría
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antonia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  Sánchez-Vallejo|New YorkThe meeting in Washington came a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     day after Netanyahu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  canceled
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the visit of two of his advisors to the U.S. capital to
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  discuss alternatives to the announced offensive on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RafahGaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  war brings
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biden and Netanyahu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  rela

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Counting and Displaying Label Counts</p>

# %%
# Counting and displaying label counts for the Spanish article
labels = [x.label_ for x in article.ents]
label_counts = Counter(labels)
print(label_counts)

items = [ent.text for ent in article.ents]
print(Counter(items).most_common(5))
# Out:
# Counter({'MISC': 130, 'PER': 50, 'ORG': 39, 'LOC': 15})
# [('PAÍS', 3), ('who', 2), ('the king of television who', 2), ('‘I', 2), ('been happier out of the closet', 2)]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Splitting Text into Sentences</p>

# %%
# Splitting text into sentences for the Spanish article
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# EL PAÍS English____Mar 27, 2024|Updated 01:59 CET|Select:- - -EspañaAméricaMéxicoColombiaChileArgentinaUSAsubscribeHHOLALOG INInternationalU.S.Economy & BusinessScienceHealthTechnologyClimatePeopleLifestyleOpinionSportsMar 27, 2024|Updated 01:59 CET|subscribe_Supreme Court seems inclined not to restrict access to abortion pill Iker Seisdedos|WashingtonAt the oral arguments in the mifepristone case, a majority of justices appeared skeptical about the legal standing of a Christian doctors’ association to sue the Food and Drug AdministrationNew York judge imposes gag order on Donald Trump in hush money caseJudge Juan M. Merchan on Tuesday cited Trump’s previous comments about him and others involved in the case, as well as a looming April 15 trial date, in granting the prosecution’s request for a gag orderBaltimore’s largest bridge collapses after being struck by shipMiguel Jiménez|BaltimoreEmergency crews have rescued two people from the water and are searching for six others.

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Visualizing Named Entities in a Sentence</p>

# %%
# Visualizing named entities in a sentence for the Spanish article
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">EL
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PAÍS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  English____Mar 27, 2024|Updated 01:59 CET|Select:- - -EspañaAméricaMéxicoColombiaChileArgentinaUSAsubscribeHHOLALOG INInternationalU.S.Economy &amp; BusinessScienceHealthTechnologyClimatePeopleLifestyleOpinionSportsMar 27, 2024|Updated 01:59
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CET|subscribe_Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  seems inclined not to restrict access to abortion pill
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Seisdedos|WashingtonAt
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the oral arguments in the mifepristone case
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     majority of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  justices
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     appeared skeptical about the legal standing of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  a Christian doctors’ association to sue the Food and Drug AdministrationNew
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  judge imposes gag order on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump in hush money caseJudge Juan M. Merchan on Tuesday cited Trump’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  previous comments about him and others involved in the case,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     as well
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  as a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     looming April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  15 trial date,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in granting the prosecution’s request for a gag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     orderBaltimore’s largest bridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  collapses after
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     being struck by shipMiguel Jiménez|BaltimoreEmergency crews
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  have rescued two
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people from the water and are searching for six others
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Token Analysis in a Sentence</p>

# %%
# Token analysis in a sentence for the Spanish article
print([(x.orth_,x.pos_, x.lemma_) for x in
  [y for y in nlp(str(sentences[0])) if not y.is_stop and y.pos_ != 'PUNCT']])
# Out:
# [('PAÍS', 'PROPN', 'PAÍS'), ('English____Mar', 'PROPN', 'English____Mar'), ('27', 'NUM', '27'), ('2024|Updated', 'NUM', '2024|updated'), ('01:59', 'NUM', '01:59'), ('CET|Select:-', 'PROPN', 'CET|Select:-'), ('-EspañaAméricaMéxicoColombiaChileArgentinaUSAsubscribeHHOLALOG', 'PROPN', '-EspañaAméricaMéxicoColombiaChileArgentinaUSAsubscribeHHOLALOG'), ('INInternationalU.S.Economy', 'PROPN', 'INInternationalU.S.Economy'), ('&', 'PROPN', '&'), ('BusinessScienceHealthTechnologyClimatePeopleLifestyleOpinionSportsMar', 'PROPN', 'BusinessScienceHealthTechnologyClimatePeopleLifestyleOpinionSportsMar'), ('27', 'NUM', '27'), ('2024|Updated', 'PROPN', '2024|Updated'), ('01:59', 'NUM', '01:59'), ('CET|subscribe_Supreme', 'VERB', 'cet|subscribe_supreme'), ('Court', 'PROPN', 'Court'), ('seems', 'PROPN', 'seems'), ('inclined', 'VERB', 'inclined'), ('not', 'ADV', 'not'), ('to', 'PROPN', 'to'), ('restrict', 'NOUN', 'restrict'), ('access', 'NOUN', 'access'), ('to', 'PROPN', 'to'), ('abortion', 'PROPN', 'abortion'), ('pill', 'PROPN', 'pill'), ('\xa0', 'SPACE', '\xa0'), ('Iker', 'PROPN', 'Iker'), ('Seisdedos|WashingtonAt', 'PROPN', 'Seisdedos|WashingtonAt'), ('the', 'PROPN', 'the'), ('oral', 'ADJ', 'oral'), ('arguments', 'NOUN', 'arguments'), ('in', 'ADP', 'in'), ('the', 'PROPN', 'the'), ('mifepristone', 'VERB', 'mifepristonir'), ('case', 'PROPN', 'case'), ('majority', 'PROPN', 'majority'), ('of', 'PROPN', 'of'), ('justices', 'ADJ', 'justiz'), ('appeared', 'VERB', 'appeared'), ('skeptical', 'ADJ', 'skeptical'), ('about', 'ADJ', 'about'), ('the', 'PROPN', 'the'), ('legal', 'ADJ', 'legal'), ('standing', 'PROPN', 'standing'), ('of', 'PROPN', 'of'), ('Christian', 'PROPN', 'Christian'), ('doctors', 'PROPN', 'doctors'), ('’', 'PROPN', '’'), ('association', 'PROPN', 'association'), ('to', 'PROPN', 'to'), ('sue', 'PROPN', 'sue'), ('the', 'PROPN', 'the'), ('Food', 'PROPN', 'Food'), ('and', 'PROPN', 'and'), ('Drug', 'PROPN', 'Drug'), ('AdministrationNew', 'PROPN', 'AdministrationNew'), ('York', 'PROPN', 'York'), ('judge', 'PROPN', 'judge'), ('imposes', 'ADJ', 'imposes'), ('gag', 'ADJ', 'gag'), ('order', 'VERB', 'order'), ('on', 'ADJ', 'on'), ('Donald', 'PROPN', 'Donald'), ('Trump', 'PROPN', 'Trump'), ('in', 'ADP', 'in'), ('hush', 'ADJ', 'hush'), ('money', 'NOUN', 'money'), ('caseJudge', 'PROPN', 'caseJudge'), ('Juan', 'PROPN', 'Juan'), ('M.', 'PROPN', 'M.'), ('Merchan', 'PROPN', 'Merchan'), ('on', 'ADJ', 'on'), ('Tuesday', 'PROPN', 'Tuesday'), ('cited', 'PROPN', 'cited'), ('Trump’s', 'PROPN', 'Trump’s'), ('previous', 'NOUN', 'previous'), ('comments', 'NOUN', 'comment'), ('about', 'ADJ', 'about'), ('him', 'PROPN', 'him'), ('and', 'PROPN', 'and'), ('others', 'PROPN', 'others'), ('involved', 'VERB', 'involved'), ('in', 'ADP', 'in'), ('the', 'PROPN', 'the'), ('case', 'PROPN', 'case'), ('as', 'PROPN', 'as'), ('well', 'PROPN', 'well'), ('as', 'PROPN', 'as'), ('looming', 'NOUN', 'looming'), ('April', 'PROPN', 'April'), ('15', 'NUM', '15'), ('trial', 'ADJ', 'trial'), ('date', 'NOUN', 'date'), ('in', 'ADP', 'in'), ('granting', 'PROPN', 'granting'), ('the', 'PROPN', 'the'), ('prosecution’s', 'PROPN', 'prosecution’s'), ('request', 'VERB', 'request'), ('for', 'PROPN', 'for'), ('gag', 'PROPN', 'gag'), ('orderBaltimore’s', 'PROPN', 'orderBaltimore’s'), ('largest', 'PROPN', 'largest'), ('bridge', 'PROPN', 'bridge'), ('collapses', 'NOUN', 'collapses'), ('after', 'PROPN', 'after'), ('being', 'PROPN', 'being'), ('struck', 'PROPN', 'struck'), ('by', 'PROPN', 'by'), ('shipMiguel', 'NOUN', 'shipmiguel'), ('Jiménez|BaltimoreEmergency', 'PROPN', 'Jiménez|BaltimoreEmergency'), ('crews', 'PROPN', 'crews'), ('have', 'ADJ', 'have'), ('rescued', 'PROPN', 'rescued'), ('two', 'PROPN', 'two'), ('people', 'VERB', 'peoplir'), ('from', 'PROPN', 'from'), ('the', 'PROPN', 'the'), ('water', 'PROPN', 'water'), ('and', 'PROPN', 'and'), ('are', 'PROPN', 'are'), ('searching', 'PROPN', 'searching'), ('for', 'PROPN', 'for'), ('six', 'PROPN', 'six'), ('others', 'PROPN', 'others')]

# %% [markdown]
# # <p style="background-color:#8502d1; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Visualizing Dependency Parsing in a Sentence</p>

# %%
# Visualizing dependency parsing in a sentence
displacy.render(nlp(str(sentences[0])), style='dep', jupyter=True, options={'distance': 140})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="4755e725e5664183950507c22c738b5f-0" class="displacy" width="17690" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">EL</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">PAÍS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">English____Mar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">27,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">2024|Updated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">01:59</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">CET|Select:- -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">-EspañaAméricaMéxicoColombiaChileArgentinaUSAsubscribeHHOLALOG</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">INInternationalU.S.Economy &amp;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">BusinessScienceHealthTechnologyClimatePeopleLifestyleOpinionSportsMar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">27,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">2024|Updated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">01:59</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">CET|subscribe_Supreme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">Court</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">seems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">inclined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">restrict</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">access</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2990">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2990">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">abortion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3270">pill</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3270">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Iker</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">Seisdedos|WashingtonAt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3830">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3830">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3970">oral</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3970">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4110">arguments</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curre

# %% [markdown]
# #### This code demonstrates Named Entity Recognition (NER) using SpaCy on sample text and web articles. It showcases token analysis, entity extraction, label counting, and visualization. Through web scraping, it extracts entities from diverse sources, displaying a versatile application of NLP techniques for information extraction and analysis.
