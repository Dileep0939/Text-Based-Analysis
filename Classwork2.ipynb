# %% [markdown]
# #                              INSIGHTS FROM TEXTUAL DATA

# %% [markdown]
# ## DATA LOADING AND EXPLORATION

# %%
# Importing the pandas library and aliasing it as 'pd'
import pandas as pd

# Defining the file path for the dataset
file = "/Users/dileepkumarkatla/Downloads/un-general-debates-blueprint.csv"

# Reading the CSV file into a Pandas DataFrame
df = pd.read_csv(file)

# Displaying the first 20 rows of the DataFrame
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %% [markdown]
# ## PRINTING A DATA FRAME

# %%
# Displaying a random sample of 20% of the DataFrame
df.sample(frac=0.2)
# Out:
#       session  year country                           country_name  \
# 4534       55  2000     IRL                                Ireland
# 2355       42  1987     LKA                              Sri Lanka
# 3601       50  1995     COD  Congo, The Democratic Republic of the
# 3615       50  1995     ERI                                Eritrea
# 4874       57  2002     DOM                     Dominican Republic
# ...       ...   ...     ...                                    ...
# 2446       43  1988     BWA                               Botswana
# 6408       65  2010     GAB                                  Gabon
# 3280       48  1993     GRC                                 Greece
# 1306       35  1980     HTI                                  Haiti
# 937        32  1977     STP                  Sao Tome and Principe
#
#                      speaker                      position  \
# 4534             Brian Cowen  Minister for Foreign Affairs
# ...

# %% [markdown]
# ## ACCESSING A DATA FRAME

# %%
# Displaying the column names of the DataFrame
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# ## PRINTING DATA TYPES OF COLUMNS

# %%
# Displaying the data types of each column in the DataFrame
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# ## PRINTING INFORMATION OF DATA

# %%
# Displaying information about the DataFrame, including non-null counts and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# ## PRINTING STATISTICAL INFORMATION OF DATA

# %%
# Displaying descriptive statistics for numerical columns in the DataFrame
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# ## ADDING A NEW COLUMN TO THE DATAFRAME

# %%
# Adding a new column 'length' to the DataFrame, representing the length of the 'text' column
df['length'] = df['text'].str.len()

# Displaying descriptive statistics for the DataFrame with the new 'length' column
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# ## PRINTING INFORMATION OF DATAFRAME

# %%
# df.describe(include='O') output will show statistics for each object (string) column in your DataFrame.
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# ## FINDING A MISSING VALUES OF DATAFRAMEE

# %%
#df.isna().sum() output will show the count of missing values for each column in your DataFrame.
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %% [markdown]
# ## REPLACING MISSING DATA

# %%
# Handling missing values by filling NaN values in the 'speaker' and 'position' columns with 'unknown'
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)

# Confirming that missing values have been successfully handled
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# ## CONVERTING TO UPPERCASE

# %%
# Converting text data to uppercase in specific columns ('speaker', 'position', 'text')
df['speaker'].str.upper()
df['position'].str.upper()
df['text'].str.upper()
# Out:
# 0       33: MAY I FIRST CONVEY TO OUR PRESIDENT THE CO...
# 1       177.\t : IT IS A FORTUNATE COINCIDENCE THAT PR...
# 2       100.\t  IT IS A PLEASURE FOR ME TO EXTEND TO Y...
# 3       155.\t  MAY I BEGIN BY EXPRESSING TO AMBASSADO...
# 4       176. NO DOUBT EACH OF US, BEFORE COMING UP TO ...
#                               ...
# 7502    ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...
# 7503    \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...
# 7504    I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...
# 7505    I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...
# 7506    ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...
# Name: text, Length: 7507, dtype: object

# %% [markdown]
# ## PRINTING A DATA WITH SPEAKER NAMED BUSH

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name          speaker   position  \
# 2876       45  1990     USA  United States      GEORGE BUSH    unknown
# 3207       47  1992     USA  United States  Mr. George BUSH  President
#
#                                                    text  length
# 2876  ﻿\nIt is really a great privilege to greet you...   15843
# 3207  Forty-seven years ago I was a young man of 21,...   21105

# %% [markdown]
# ## PLOTTING CHARTS

# %%
# Plotting the length of texts
df['length'].plot(title='Distribution of Text Lengths', xlabel='Index', ylabel='Text Length')
# Out:
# <Axes: title={'center': 'Distribution of Text Lengths'}, xlabel='Index', ylabel='Text Length'>

# %% [markdown]
# ## HISTOGRAM

# %%
# Creating a histogram of text lengths in the DataFrame
df['length'].plot(kind='hist', bins=30, title='Histogram of Text Lengths', xlabel='Text Length', ylabel='Frequency')
# Out:
# <Axes: title={'center': 'Histogram of Text Lengths'}, xlabel='Text Length', ylabel='Frequency'>

# %% [markdown]
# ## BOX PLOT

# %%
# Plotting the distribution of text lengths using a box plot
df['length'].plot(kind='box', vert=False, title='Box Plot of Text Lengths', xlabel='Text Length')
# Out:
# <Axes: title={'center': 'Box Plot of Text Lengths'}, xlabel='Text Length'>

# %% [markdown]
# ## COUNTRY-WISE TEXT LENGTH DISTRIBUTION

# %%
# Importing seaborn for visualization
import seaborn as sns

# Filtering data for specific countries and plotting text length distribution using a box plot
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8)
# Out:
# /Users/dileepkumarkatla/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #                    TEXT TOKENIZATION AND STOPWORD REMOVAL

# %% [markdown]
# ## REGEX TO PULL OUT WORDS

# %%
# Tokenizing the text in the 'text' column using a custom function 'tokenize'
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# Testing the tokenize function on a sample text
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ## STOPWORDS FROM DATASET

# %%
# Downloading the NLTK stopwords dataset
import nltk
nltk.download('stopwords')

# Creating a set of English stopwords
stopwords = set(nltk.corpus.stopwords.words('english'))

# Displaying the set of stopwords
print(stopwords)
# Out:
# {'didn', 'nor', 'are', 'after', 'have', 'does', 'me', 'because', 'up', 'ain', 'their', 'our', 'same', 'few', 'm', "she's", "won't", 'whom', 'further', 'once', 'these', 'don', 'of', 'that', 'for', 'while', 'its', 'until', 'how', 'no', 'very', 'in', 'than', 'out', 'who', 'she', "shouldn't", 'we', 'it', 'shan', "should've", "don't", "needn't", "shan't", 'about', 'been', 'not', 'doesn', 'haven', 'against', 'itself', 'and', 'or', 'from', 'ours', 're', 'doing', 've', 'mightn', "mustn't", 'is', 'to', 'won', 'then', 'them', 'couldn', 'did', "doesn't", 'hadn', 'between', 's', 'had', 'so', 'by', 'your', 'own', 'some', 'o', 'as', 'before', 'which', 'should', 'wouldn', 'shouldn', 'those', 'most', "it's", "you're", 'hasn', 'y', 'myself', 'they', 'yourself', "that'll", 'do', 'there', "aren't", 'weren', 'on', 'any', 'during', 'again', "haven't", 'his', 'him', 'below', 'be', 'off', 'needn', 'were', 'ma', 'all', 'over', "you'll", 'where', 'now', 'll', 'ourselves', 'through', 'more', 'isn', 'if', 'mus
# ...

# %% [markdown]
# ## REMOVING STOPWORDS

# %%
# Removing stopwords from tokens
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# Testing the remove_stop function
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ## CREATING THE PIPELINE

# %%
# Defining a preprocessing pipeline
pipeline = [str.lower, tokenize, remove_stop]

# Applying the preprocessing pipeline to the 'text' column and creating 'tokens' column
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7503       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7504       70  2015     ZAF  South Africa                         Jacob Zuma
# 7505       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7506       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text  length  \
# 7502  President  On behalf of the people and the Government of ...   10568
# 7503  President  \nSeventy years have passed since the establis...   25430
# 7504  President  I should like to congratulate the President an...   13662
# 7505  President  I would like to begin by thanking the Secretar...   14247
# 7506  President  Allow me at the outset to extend to Mr. Mogens...   11013
#
# ...

# %% [markdown]
# # TOKEN FREQUENCY ANALYSIS

# %% [markdown]
# ## COUNTING THE TOKENS

# %%
# Importing Counter to count token frequencies
from collections import Counter

# Counting token frequencies in a sample text
tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ## WORD FREQUENCY ANALYSIS

# %%
# Updating token frequencies with more tokens
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ## FREQUENCY OF DATAFRAME

# %%
# Counting token frequencies across the entire DataFrame
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %% [markdown]
# ## SORT AND DISPLAY

# %%
# Creating a DataFrame from the Counter and sorting by frequency
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %% [markdown]
# ## FINDING INFORMATION OF FREQUENCY

# %%
freq_df.describe()
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# ## BAR CHART

# %%
# Plotting the top 15 words by frequency
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# # WORD CLOUD VISUALIZATION

# %%
# Importing WordCloud and matplotlib for visualization
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Extracting text for WordCloud for the year 2015 and country USA
text = df.query("year==2015 and country=='USA'")['text'].values[0]

# Generating and displaying WordCloud
plt.figure(figsize=(14, 7))
wc = WordCloud(max_words=100, stopwords=stopwords, colormap='viridis')  # Added colormap
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.title('WordCloud for USA in 2015', fontsize=16)  # Added title
plt.axis("off")
plt.show()

# %%
# Importing WordCloud and matplotlib for visualization
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Extracting text for WordCloud for the year 2015 and country USA
text = df.query("year==2015 and country=='USA'")['text'].values[0]

# Generating WordCloud with improved settings
wordcloud = WordCloud(width=800, height=400, max_words=200, background_color='white', colormap='viridis', stopwords=stopwords)

# Generate the WordCloud
wordcloud.generate(text)

# Display the WordCloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('WordCloud for USA in 2015', fontsize=16)
plt.axis("off")
plt.show()
